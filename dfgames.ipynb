# %%
import pandas as pd


df_games = pd.read_csv("df_games.csv")

# %%
df_games
# Out:
#                  user_id  item_id_x  recommend  \
# 0      76561197970982479       1250       True
# 1      76561198060901683     313120       True
# 2      76561198094455687     200210      False
# 3               FireHalo        620       True
# 4             xXGeronimo     295110       True
# ...                  ...        ...        ...
# 16710  76561198155824473     220460       True
# 16711            Azzaaaa     222880       True
# 16712        uncleshenny        730       True
# 16713  76561198161220449       4000       True
# 16714   cyvoxfromyoutube     433850       True
#
#                                                   review  \
# 0      Simple yet with great replayability. In my opi...
# 1      This is a beautiful Game, but if it was co-op ...
# 2      bad game i was rich then the value of my items...
# 3                        one of the best games ever made
# 4      Ok let me say this, ANYONE WHO SAYS THIS GAME ...
# ...
